# %%
import requests
import pandas as pd

# %%
# Base URLs for the API
dataset_id = "GFSMAB2020"
base_url = "http://dataservices.imf.org/REST/SDMX_JSON.svc"

def get_dimensions(dataset_id):
    url = f"{base_url}/DataStructure/{dataset_id}"
    response = requests.get(url)
    response.raise_for_status()
    data = response.json()
    dimensions = []
    
    # Inspect the structure of the response
    if "Structure" in data and "KeyFamilies" in data["Structure"]:
        key_family = data["Structure"]["KeyFamilies"]["KeyFamily"]
        
        # Ensure "Components" and "Dimension" exist
        components = key_family.get("Components", {}).get("Dimension", [])
        if isinstance(components, list):
            for component in components:
                dimensions.append({
                    "Dimension": component.get("@codelist", "UnknownCodelist"),
                    "Name": component.get("@id", "UnknownID")
                })
        else:
            print("Unexpected structure for dimensions:", components)
    
    return dimensions


# Function to retrieve possible values for a given dimension
def get_dimension_values(codelist_id):
    url = f"{base_url}/CodeList/{codelist_id}"
    response = requests.get(url)
    response.raise_for_status()
    data = response.json()
    values = []
    if "Structure" in data and "CodeLists" in data["Structure"]:
        codes = data["Structure"]["CodeLists"]["CodeList"]["Code"]
        for code in codes:
            values.append({
                "Code": code["@value"],
                "Description": code["Description"]["#text"]
            })
    return values

# Retrieve dimensions for the dataset
print("Fetching dimensions...")
dimensions = get_dimensions(dataset_id)

# Fetch possible values for each dimension
all_dimension_values = {}
for dimension in dimensions:
    print(f"Fetching values for dimension: {dimension['Name']}")
    values = get_dimension_values(dimension["Dimension"])
    all_dimension_values[dimension["Name"]] = values

# Save the dimensions and their values to a DataFrame
output = []
for dimension, values in all_dimension_values.items():
    for value in values:
        output.append({
            "Dimension": dimension,
            "Code": value["Code"],
            "Description": value["Description"]
        })

df = pd.DataFrame(output)
df.to_csv("dimensions_and_values.csv", index=False)
print("Dimensions and values saved to 'dimensions_and_values.csv'")
# Out:
# Fetching dimensions...
# Fetching values for dimension: UnknownID
# Fetching values for dimension: UnknownID
# Fetching values for dimension: UnknownID
# Fetching values for dimension: UnknownID
# Fetching values for dimension: UnknownID
# Dimensions and values saved to 'dimensions_and_values.csv'

# %%
import requests
import pandas as pd

# 1. Define your base URL and dataset
BASE_URL = "http://dataservices.imf.org/REST/SDMX_JSON.svc/"
DATASET_ID = "GFSMAB2017"

# 2. Use wildcards for area, sector, unit, and indicator (and 'A' for annual frequency)
#    Key format: "CompactData/<DATASET_ID>/A.*.*.*.*"
wildcard_key = f"CompactData/{DATASET_ID}/A.*.*.*.*"

# 3. Make the request
print(f"Requesting data with key: {wildcard_key}")
response = requests.get(f"{BASE_URL}{wildcard_key}")
if response.status_code != 200:
    print("Server error or invalid request:", response.status_code, response.text)
    # Exit or handle error as needed
    exit()

# 4. Parse JSON
data_json = response.json()

# 5. Navigate to the Series
data_set = data_json.get("CompactData", {}).get("DataSet")
series = data_set.get("Series") if data_set else None

# If there's no data, exit early
if not series:
    print("No data found for wildcard query.")
    exit()

# 6. Ensure series is a list
if isinstance(series, dict):
    series = [series]

# Prepare a list to store all observations
results = []

# 7. Iterate over each series in the data
for s in series:
    # Each series has dimension attributes like @FREQ, @REF_AREA, @REF_SECTOR, etc.
    freq = s.get("@FREQ")
    ref_area = s.get("@REF_AREA")
    sector = s.get("@REF_SECTOR")
    unit = s.get("@UNIT_MEASURE")
    indicator = s.get("@CLASSIFICATION")

    # 8. Observations are in s["Obs"], which can be a list or a single dict
    obs_list = s.get("Obs", [])
    if isinstance(obs_list, dict):
        obs_list = [obs_list]

    for obs in obs_list:
        time_period = obs.get("@TIME_PERIOD")
        value = obs.get("@OBS_VALUE")

        # Only store non-missing values
        if value is not None:
            results.append({
                "FREQ": freq,
                "AREA_CODE": ref_area,
                "SECTOR_CODE": sector,
                "UNIT_CODE": unit,
                "INDICATOR_CODE": indicator,
                "TIME_PERIOD": time_period,
                "VALUE": value
            })

# 9. Convert to a DataFrame
df = pd.DataFrame(results)
print(f"Retrieved {len(df)} rows from the wildcard request.")

# 10. Save to CSV
output_file = "gfsmab2017_wildcard.csv"
df.to_csv(output_file, index=False)
print(f"Data saved to {output_file}")
# Out:
# Requesting data with key: CompactData/GFSMAB2017/A.*.*.*.*
# No data found for wildcard query.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 40
#      37 results = []
#      39 # 7. Iterate over each series in the data
# ---> 40 for s in series:
#      41     # Each series has dimension attributes like @FREQ, @REF_AREA, @REF_SECTOR, etc.
#      42     freq = s.get("@FREQ")
#      43     ref_area = s.get("@REF_AREA")
#
# TypeError: 'NoneType' object is not iterable
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/{database ID}/{frequency}.{item1 from
# dimension1}+{item2 from dimension1}+{item N from dimension1}.{item1 from
# dimension2}+{item2 from dimension2}+{item M from dimension2}?startPeriod={start
# date}&endPeriod={end date}

# %%
import requests
import time

# Base URL for IMF API
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'

# Dataset details
dataset = 'GFSMAB2017'
indicator = 'G63_FD4'  # Example: Gross debt (D4) at market value
sector = 'S1311B'      # Example: Budgetary central government
unit = 'XDC'           # Domestic currency
frequency = 'A'        # Annual data

# Function to fetch geographical areas
def get_countries():
    codelist_key = f'CodeList/CL_AREA_{dataset}'
    response = requests.get(f'{url}{codelist_key}')
    response.raise_for_status()
    data = response.json()
    return [
        code['@value'] for code in 
        data['Structure']['CodeLists']['CodeList']['Code']
    ]

# Function to fetch data for a specific country
def fetch_data(country):
    key = f'CompactData/{dataset}/{frequency}.{country}.{sector}.{unit}.{indicator}'
    response = requests.get(f'{url}{key}')
    if response.status_code == 200:
        try:
            data = response.json()
            series = data.get('CompactData', {}).get('DataSet', {}).get('Series', {})
            return {
                'country': country,
                'data': series.get('Obs', [])
            }
        except Exception as e:
            return {'country': country, 'error': str(e)}
    else:
        return {'country': country, 'error': f"HTTP {response.status_code}"}

# Fetch list of countries
countries = get_countries()
print(f"Retrieved {len(countries)} countries.")

# Loop through countries and fetch data
results = []
for country in countries:
    print(f"Fetching data for {country}...")
    result = fetch_data(country)
    results.append(result)
    time.sleep(0.5)  # To avoid overwhelming the server

# Process results
for result in results:
    if 'error' in result:
        print(f"Error fetching data for {result['country']}: {result['error']}")
    else:
        print(f"Data for {result['country']}: {result['data']}")

# Example: Save results to a file
import json
with open('imf_data.json', 'w') as f:
# Fetching data for NG...
# Fetching data for NO...
# Fetching data for OM...
# Fetching data for PK...
# Fetching data for PW...
# Fetching data for PA...
# Fetching data for PG...
# Fetching data for PY...
# Fetching data for PE...
# Fetching data for PH...
# Fetching data for PL...
# Fetching data for PT...
# Fetching data for QA...
# Fetching data for RO...
# Fetching data for RU...
# Fetching data for RW...
# Fetching data for WS...
# Fetching data for SM...
# Fetching data for ST...
# Fetching data for SA...
# Fetching data for SN...
# Fetching data for CS...
# Fetching data for RS...
# Fetching data for SC...
# Fetching data for SL...
# Fetching data for SG...
# Fetching data for SK...
# Fetching data for SI...
# Fetching data for SB...
# Fetching data for SO...
# Fetching data for ZA...
# Fetching data for SS...
# Fetching data for ES...
# Fetching data for LK...
# Fetching data for KN...
# Fetching data for LC...
# Fetching data for VC...
# Fetching data for SD...
# Fetching data for SR...
# Fetching data for SZ...
# Fetching data for SE...
# Fetching data for CH...
# Fetching data for SY...
# Fetching data for TJ...
# Fetching data for TZ...
# Fetching data for TH...
# Fetching data for TL...
# Fetching data for TG...
# Fetching data for TO...
# Fetching data for TT...
# Fetching data for TN...
# Fetching data for TR...
# Fetching data for TM...
# Fetching data for TV...
# Fetching data for UG...
# Fetching data for UA...
# Fetching data for AE...
# Fetching data for GB...
# Fetching data for US...
# Fetching data for UY...
# Fetching data for UZ...
# Fetching data for VU...
# Fetching data for VE...
# Fetching data for VN...
# Fetching data for PS...
# Fetching data for 1C_473...
# Fetching data for YE...
# Fetching data for ZM...
# Fetching data for ZW...
# Fetching data for 1C_AAA...
# Fetching data for 1C_ALLC...
# Fetching data for 1C_ALL...
# Fetching data for 1C_Al_Countries_for_Dissemination_Online...
# Fetching data for 1C_GFSY_2014_Country_Pages...
# Fetching data for 1C_ALLG...
# Fetching data for 1C_Template_I...
# Fetching data for 1C_Template_II...
# Fetching data for 1C_Template_III...
# Fetching data for 1C_Template_IV...
# Fetching data for 1C_All_Countries_for_Dissemination...
# Fetching data for S1311B...
# Fetching data for S13...
# Fetching data for S1321...
# Fetching data for S1311...
# Fetching data for All Countries Table A and B...
# Data for AF: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for AL: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for DZ: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for AO: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for AI: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for AG: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for AR: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'A', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'A', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'A', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@V ...
# Data for AM: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for AW: []
# Data for AU: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES ...
# Data for AT: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@NATURE_OF_DATA': 'NA', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP',  ...
# ...
# Data for 1C_473: []
# Data for YE: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for ZM: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for ZW: [{'@TIME_PERIOD': '1972', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1973', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1974', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1975', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1976', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1977', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1978', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1979', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1980', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1981', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1982', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1983', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1984', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1985', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1986', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1987', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1988', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1989', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1990', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1991', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1992', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1993', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1994', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1995', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1996', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1997', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH': 'NP'}, {'@TIME_PERIOD': '1998', '@BASES_OF_RECORDING_GROSSNET': 'NP', '@VALUATION': 'MV', '@OBS_STATUS': 'NA', '@BASES_OF_RECORDING_CASH_NON_CASH ...
# Data for 1C_AAA: []
# Data for 1C_ALLC: []
# Data for 1C_ALL: []
# Data for 1C_Al_Countries_for_Dissemination_Online: []
# Data for 1C_GFSY_2014_Country_Pages: []
# Data for 1C_ALLG: []
# Data for 1C_Template_I: []
# Data for 1C_Template_II: []
# Data for 1C_Template_III: []
# Data for 1C_Template_IV: []
# Data for 1C_All_Countries_for_Dissemination: []
# Data for S1311B: []
# Data for S13: []
# Data for S1321: []
# Data for S1311: []
# Data for All Countries Table A and B: []
# Results saved to 'imf_data.json'.

# %%
import requests
import pandas as pd
import time  # To enable pauses between requests

# Base URL
url = "http://dataservices.imf.org/REST/SDMX_JSON.svc/"
dataset_id = "GFSMAB2017"

###############################################################################
# 1. Retrieve codelists for countries, sectors, and units
###############################################################################
def fetch_codelist(codelist_id):
    """Fetches and returns a list of (code, description) tuples."""
    response = requests.get(f"{url}CodeList/{codelist_id}")
    response.raise_for_status()
    data = response.json()
    # Navigate to the Code section
    codes = data["Structure"]["CodeLists"]["CodeList"]["Code"]
    return [(c["@value"], c["Description"]["#text"]) for c in codes]

try:
    area_codes = fetch_codelist("CL_AREA_GFSMAB2017")
    sector_codes = fetch_codelist("CL_SECTOR_GFSMAB2017")
    unit_codes = fetch_codelist("CL_UNIT_GFSMAB2017")
except Exception as e:
    print(f"Error fetching codelists: {e}")
    raise SystemExit

# Print how many codes were retrieved
print(f"Fetched {len(area_codes)} area codes.")
print(f"Fetched {len(sector_codes)} sector codes.")
print(f"Fetched {len(unit_codes)} unit codes.")

###############################################################################
# 2. Automated Loop to Retrieve Data
###############################################################################
results = []

# We'll use annual frequency ('A') for the FREQ dimension
# The dimension order (based on the dataset structure) is:
#   1) FREQ  2) AREA  3) SECTOR  4) UNIT  5) INDICATOR
# Final key format: "CompactData/GFSMAB2017/A.<AREA>.<SECTOR>.<UNIT>.<INDIC>"
for area_val, area_desc in area_codes:
    for sector_val, sector_desc in sector_codes:
        for unit_val, unit_desc in unit_codes:
            for indicator in indicators:
                key = (f"CompactData/{dataset_id}/A."
                       f"{area_val}.{sector_val}.{unit_val}.{indicator}")

                # Pause briefly between requests
                time.sleep(1)

                try:
                    resp = requests.get(f"{url}{key}")
                    resp.raise_for_status()
                    data_json = resp.json()
                except Exception as e:
                    # You might want to log failures or skip them
                    print(f"Error retrieving {key}: {e}")
                    continue

                # Parse the time-series data (if present)
                # Typical structure:
                # data_json["CompactData"]["DataSet"]["Series"][ ... ]["Obs"]
                try:
                    series_data = data_json["CompactData"]["DataSet"].get("Series")
                    # If there's no 'Series', skip
                    if not series_data:
                        continue

                    # 'Series' can be a dict or list; handle both:
                    if isinstance(series_data, dict):
                        series_data = [series_data]  # Wrap single dict in list

                    for s in series_data:
                        # Observations are typically in s["Obs"]
                        obs_list = s.get("Obs", [])
                        if isinstance(obs_list, dict):
                            obs_list = [obs_list]  # If single obs is a dict

                        for obs in obs_list:
                            time_period = obs.get("@TIME_PERIOD")
                            value = obs.get("@OBS_VALUE")

                            # Only store if value exists
                            if value is None:
                                continue

                            results.append({
                                "AREA_CODE": area_val,
                                "AREA_NAME": area_desc,
                                "SECTOR_CODE": sector_val,
                                "SECTOR_NAME": sector_desc,
                                "UNIT_CODE": unit_val,
                                "UNIT_NAME": unit_desc,
                                "INDICATOR": indicator,
                                "TIME_PERIOD": time_period,
                                "VALUE": value
                            })

                except KeyError:
                    # If the expected keys aren't there, skip
                    continue

###############################################################################
# 3. Convert to DataFrame
###############################################################################
df = pd.DataFrame(results)
print(f"\nRetrieved {len(df)} observations.")
print(df.head(10))

# Example: Save to CSV
df.to_csv("imf_gfsmab2017_data.csv", index=False)
# Out:
# Fetched 219 area codes.
# Fetched 8 sector codes.
# Fetched 2 unit codes.
# Error retrieving CompactData/GFSMAB2017/A.DZ.S1314.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S1321.XDC.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S13112.XDC_R_B1GQ.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S1313.XDC.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S1314.XDC.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S1314.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S1312.XDC.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.AZ.S1312.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BS.S1311B.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BS.S13.XDC_R_B1GQ.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BS.S1313.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BS.S1314.XDC_R_B1GQ.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BS.S1312.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BS.S1312.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S1311B.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S1311.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S1311.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S1321.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S1321.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S13112.XDC.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S13112.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S13.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BH.S13.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S1311.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S1321.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S1321.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S1321.XDC_R_B1GQ.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S13112.XDC.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S1314.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BD.S1312.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BB.S1311B.XDC.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BB.S1311B.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BB.S1311B.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BB.S1321.XDC_R_B1GQ.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BB.S13112.XDC_R_B1GQ.GNLB__Z: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.BO.S1311.XDC.G33_F: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.CV.S1321.XDC.G63N_FD4: Expecting value: line 1 column 1 (char 0)
# Error retrieving CompactData/GFSMAB2017/A.CV.S1313.XDC_R_B1GQ.G33_F: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 57
#      54 time.sleep(1)
#      56 try:
# ---> 57     resp = requests.get(f"{url}{key}")
#      58     resp.raise_for_status()
#      59     data_json = resp.json()
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/http/client.py:1411, in HTTPConnection.getresponse(self)
#    1409 try:
#    1410     try:
# -> 1411         response.begin()
#    1412     except ConnectionError:
#    1413         self.close()
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/http/client.py:324, in HTTPResponse.begin(self)
#     322 # read until we get a non-100 response
#     323 while True:
# --> 324     version, status, reason = self._read_status()
#     325     if status != CONTINUE:
#     326         break
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/http/client.py:285, in HTTPResponse._read_status(self)
#     284 def _read_status(self):
# --> 285     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     286     if len(line) > _MAXLINE:
#     287         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/hidden_debt_gsf/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import requests

# Base URL
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'

# Function to query codelists
def fetch_codelist(codelist_key):
    try:
        response = requests.get(f'{url}{codelist_key}')
        response.raise_for_status()
        data = response.json()
        print(f"Codelist {codelist_key} retrieved successfully.")
        print("Sample data:", data)
    except requests.exceptions.RequestException as e:
        print(f"Request failed for codelist {codelist_key}: {e}")
    except KeyError as e:
        print(f"KeyError: {e}. Check the response structure.")

# Dataset-specific codelists to test
codelists = [
    'CodeList/CL_FREQ',
    'CodeList/CL_AREA_GFSMAB2017',
    'CodeList/CL_SECTOR_GFSMAB2017',
    'CodeList/CL_UNIT_GFSMAB2017',
    'CodeList/CL_INDICATOR_GFSMAB2017'
]

# Fetch each codelist
for cl in codelists:
    print(f"\nFetching codelist: {cl}")
    fetch_codelist(cl)
# Out:
# Fetching codelist: CodeList/CL_FREQ
# Codelist CodeList/CL_FREQ retrieved successfully.
# Sample data: {'Error': 'Prognoz.SDMX.WebService.Exceptions.REST.RESTFaultException: Internal Server Error (Fault Detail is equal to There is an issue while retrieving the data, please check your query or contact an administrator. GKey = ae7bf460-5c9e-4f19-97d1-21f59b7173f9).'}
#
# Fetching codelist: CodeList/CL_AREA_GFSMAB2017
# Codelist CodeList/CL_AREA_GFSMAB2017 retrieved successfully.
# Sample data: {'Structure': {'@xmlns:xsd': 'http://www.w3.org/2001/XMLSchema', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure https://registry.sdmx.org/schemas/v2_0/SDMXStructure.xsd http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message https://registry.sdmx.org/schemas/v2_0/SDMXMessage.xsd', 'Header': {'ID': 'aae21dc1-9a11-4f2f-aded-512241cee121', 'Test': 'false', 'Prepared': '2025-01-15T08:14:21', 'Sender': {'@id': '1C0', 'Name': {'@xml:lang': 'en', '#text': 'IMF'}, 'Contact': {'URI': 'http://www.imf.org', 'Telephone': '+ 1 (202) 623-6220'}}, 'Receiver': {'@id': 'ZZZ'}}, 'CodeLists': {'CodeList': {'@id': 'CL_AREA_GFSMAB2017', '@agencyID': 'IMF', '@version': '1.0', '@isFinal': 'true', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'Name': {'@xml:lang': 'en', '#text': 'Geographical Areas'}, 'Code': [{'@value': 'AF', 'Description': {'@xml:lang': 'en', '#text': 'Afghanistan'}}, {'@value': 'AL', 'Description': {'@xml:lang': 'en', '#text': 'Albania'}}, {'@value': 'DZ', 'Description': {'@xml:lang': 'en', '#text': 'Algeria'}}, {'@value': 'AO', 'Description': {'@xml:lang': 'en', '#text': 'Angola'}}, {'@value': 'AI', 'Description': {'@xml:lang': 'en', '#text': 'Anguilla'}}, {'@value': 'AG', 'Description': {'@xml:lang': 'en', '#text': 'Antigua and Barbuda'}}, {'@value': 'AR', 'Description': {'@xml:lang': 'en', '#text': 'Argentina'}}, {'@value': 'AM', 'Description': {'@xml:lang': 'en', '#text': 'Armenia'}}, {'@value': 'AW', 'Description': {'@xml:lang': 'en', '#text': 'Aruba'}}, {'@value': 'AU', 'Description': {'@xml:lang': 'en', '#text': 'Australia'}}, {'@value': 'AT', 'Description': {'@xml:lang': 'en', '#text': 'Austria'}}, {'@value': 'AZ', 'Description': {'@xml:lang': 'en', '#text': 'Azerbaijan'}}, {'@value': 'BS', 'Description': {'@xml:lang': 'en', '#text': 'Bahamas'}}, {'@value': 'BH', 'Description': {'@xml:lang': 'en', '#text': 'Bahrain'}}, {'@value': 'BD', 'Description': {'@xml:lang': 'en', '#text': 'Bangladesh'}}, {'@value': 'BB', 'Description': {'@xml:lang': 'en', '#text': 'Barbados'}}, {'@value': 'BY', 'Description': {'@xml:lang': 'en', '#text': 'Belarus'}}, {'@value': 'BE', 'Description': {'@xml:lang': 'en', '#text': 'Belgium'}}, {'@value': 'BZ', 'Description': {'@xml:lang': 'en', '#text': 'Belize'}}, {'@value': 'BJ', 'Description': {'@xml:lang': 'en', '#text': 'Benin'}}, {'@value': 'BT', 'Description': {'@xml:lang': 'en', '#text': 'Bhutan'}}, {'@value': 'BO', 'Description': {'@xml:lang': 'en', '#text': 'Bolivia'}}, {'@value': 'BA', 'Description': {'@xml:lang': 'en', '#text': 'Bosnia and Herzegovina'}}, {'@value': 'BW', 'Description': {'@xml:lang': 'en', '#text': 'Botswana'}}, {'@value': 'BR', 'Description': {'@xml:lang': 'en', '#text': 'Brazil'}}, {'@value': 'BN', 'Description': {'@xml:lang': 'en', '#text': 'Brunei Darussalam'}}, {'@value': 'BG', 'Description': {'@xml:lang': 'en', '#text': 'Bulgaria'}}, {'@value': 'BF', 'Description': {'@xml:lang': 'en', '#text': 'Burkina Faso'}}, {'@value': 'BI', 'Description': {'@xml:lang': 'en', '#text': 'Burundi'}}, {'@value': 'CV', 'Description': {'@xml:lang': 'en', '#text': 'Cape Verde'}}, {'@value': 'KH', 'Description': {'@xml:lang': 'en', '#text': 'Cambodia'}}, {'@value': 'CM', 'Description': {'@xml:lang': 'en', '#text': 'Cameroon'}}, {'@value': 'CA', 'Description': {'@xml:lang': 'en', '#text': 'Canada'}}, {'@value': 'KY', 'Description': {'@xml:lang': 'en', '#text': 'Cayman Islands'}}, {'@value': 'CF', 'Description': {'@xml:lang': 'en', '#text': 'Central African Republic'}}, {'@value': 'TD', 'Description': {'@xml:lang': 'en', '#text': 'Chad'}}, {'@value': 'CL', 'Description': {'@xml:lang': 'en', '#text': 'Chile'}}, {'@value': 'HK', 'Description': {'@xml:lang': 'en', '#text': 'Hong Kong, China'}}, {'@value': 'MO', 'Description': {'@xml:lang': 'en', '#text': 'Macao'}}, {'@value': 'CN', 'Descrip ...
#
# Fetching codelist: CodeList/CL_SECTOR_GFSMAB2017
# Codelist CodeList/CL_SECTOR_GFSMAB2017 retrieved successfully.
# Sample data: {'Structure': {'@xmlns:xsd': 'http://www.w3.org/2001/XMLSchema', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure https://registry.sdmx.org/schemas/v2_0/SDMXStructure.xsd http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message https://registry.sdmx.org/schemas/v2_0/SDMXMessage.xsd', 'Header': {'ID': 'b04a162a-c97a-49be-9d65-7f83a96a3ce3', 'Test': 'false', 'Prepared': '2025-01-15T08:14:21', 'Sender': {'@id': '1C0', 'Name': {'@xml:lang': 'en', '#text': 'IMF'}, 'Contact': {'URI': 'http://www.imf.org', 'Telephone': '+ 1 (202) 623-6220'}}, 'Receiver': {'@id': 'ZZZ'}}, 'CodeLists': {'CodeList': {'@id': 'CL_SECTOR_GFSMAB2017', '@agencyID': 'IMF', '@version': '1.0', '@isFinal': 'true', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'Name': {'@xml:lang': 'en', '#text': 'Sector'}, 'Code': [{'@value': 'S1311B', 'Description': {'@xml:lang': 'en', '#text': 'Budgetary central government'}}, {'@value': 'S1311', 'Description': {'@xml:lang': 'en', '#text': 'Central government (excl. social security funds)'}}, {'@value': 'S1321', 'Description': {'@xml:lang': 'en', '#text': 'Central government (incl. social security funds)'}}, {'@value': 'S13112', 'Description': {'@xml:lang': 'en', '#text': 'Extrabudgetary central government'}}, {'@value': 'S13', 'Description': {'@xml:lang': 'en', '#text': 'General government'}}, {'@value': 'S1313', 'Description': {'@xml:lang': 'en', '#text': 'Local governments'}}, {'@value': 'S1314', 'Description': {'@xml:lang': 'en', '#text': 'Social security funds'}}, {'@value': 'S1312', 'Description': {'@xml:lang': 'en', '#text': 'State governments'}}]}}}}
#
# Fetching codelist: CodeList/CL_UNIT_GFSMAB2017
# Codelist CodeList/CL_UNIT_GFSMAB2017 retrieved successfully.
# Sample data: {'Structure': {'@xmlns:xsd': 'http://www.w3.org/2001/XMLSchema', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure https://registry.sdmx.org/schemas/v2_0/SDMXStructure.xsd http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message https://registry.sdmx.org/schemas/v2_0/SDMXMessage.xsd', 'Header': {'ID': '711117e7-8ee0-4cec-b00c-70f28cddbede', 'Test': 'false', 'Prepared': '2025-01-15T08:14:21', 'Sender': {'@id': '1C0', 'Name': {'@xml:lang': 'en', '#text': 'IMF'}, 'Contact': {'URI': 'http://www.imf.org', 'Telephone': '+ 1 (202) 623-6220'}}, 'Receiver': {'@id': 'ZZZ'}}, 'CodeLists': {'CodeList': {'@id': 'CL_UNIT_GFSMAB2017', '@agencyID': 'IMF', '@version': '1.0', '@isFinal': 'true', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'Name': {'@xml:lang': 'en', '#text': 'Unit'}, 'Code': [{'@value': 'XDC', 'Description': {'@xml:lang': 'en', '#text': 'Domestic currency'}}, {'@value': 'XDC_R_B1GQ', 'Description': {'@xml:lang': 'en', '#text': 'Percent of GDP'}}]}}}}
#
# Fetching codelist: CodeList/CL_INDICATOR_GFSMAB2017
# Codelist CodeList/CL_INDICATOR_GFSMAB2017 retrieved successfully.
# Sample data: {'Structure': {'@xmlns:xsd': 'http://www.w3.org/2001/XMLSchema', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure https://registry.sdmx.org/schemas/v2_0/SDMXStructure.xsd http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message https://registry.sdmx.org/schemas/v2_0/SDMXMessage.xsd', 'Header': {'ID': '08c0a4b5-06f1-46c1-8918-aa19b2b99ca4', 'Test': 'false', 'Prepared': '2025-01-15T08:14:22', 'Sender': {'@id': '1C0', 'Name': {'@xml:lang': 'en', '#text': 'IMF'}, 'Contact': {'URI': 'http://www.imf.org', 'Telephone': '+ 1 (202) 623-6220'}}, 'Receiver': {'@id': 'ZZZ'}}, 'CodeLists': {'CodeList': {'@id': 'CL_INDICATOR_GFSMAB2017', '@agencyID': 'IMF', '@version': '1.0', '@isFinal': 'true', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'Name': {'@xml:lang': 'en', '#text': 'Indicator'}, 'Code': [{'@value': 'G21__Z', 'Description': {'@xml:lang': 'en', '#text': 'Compensation of employees'}}, {'@value': 'G23__Z', 'Description': {'@xml:lang': 'en', '#text': 'Consumption of fixed capital'}}, {'@value': 'G63_F3T4', 'Description': {'@xml:lang': 'en', '#text': 'D1 debt liabilities at market value '}}, {'@value': 'G63_FD2', 'Description': {'@xml:lang': 'en', '#text': 'D2 debt liabilities at market value '}}, {'@value': 'G63_FD3', 'Description': {'@xml:lang': 'en', '#text': 'D3 debt liabilities at market value '}}, {'@value': 'G63NC_FD4', 'Description': {'@xml:lang': 'en', '#text': 'Debt, net of highly liquid assets'}}, {'@value': 'G2M__Z', 'Description': {'@xml:lang': 'en', '#text': 'Expenditure'}}, {'@value': 'G2__Z', 'Description': {'@xml:lang': 'en', '#text': 'Expense'}}, {'@value': 'G2G__Z', 'Description': {'@xml:lang': 'en', '#text': 'Expense, excluding consumption of fixed capital'}}, {'@value': 'G26__Z', 'Description': {'@xml:lang': 'en', '#text': 'Grants expense'}}, {'@value': 'G13__Z', 'Description': {'@xml:lang': 'en', '#text': 'Grants revenue'}}, {'@value': 'G63_FD4', 'Description': {'@xml:lang': 'en', '#text': 'Gross debt (D4) at market value '}}, {'@value': 'GGOB__Z', 'Description': {'@xml:lang': 'en', '#text': 'Gross operating balance'}}, {'@value': 'G24__Z', 'Description': {'@xml:lang': 'en', '#text': 'Interest expense'}}, {'@value': 'G31_NG', 'Description': {'@xml:lang': 'en', '#text': 'Investment in nonfinancial assets'}}, {'@value': 'G32_F', 'Description': {'@xml:lang': 'en', '#text': 'Net acquisition of financial assets'}}, {'@value': 'G63N_FD4', 'Description': {'@xml:lang': 'en', '#text': 'Net debt'}}, {'@value': 'G6M2_F', 'Description': {'@xml:lang': 'en', '#text': 'Net financial worth'}}, {'@value': 'G33_F', 'Description': {'@xml:lang': 'en', '#text': 'Net incurrence of liabilities'}}, {'@value': 'GNLB__Z', 'Description': {'@xml:lang': 'en', '#text': 'Net lending (+) / Net borrowing (-)'}}, {'@value': 'GNOB__Z', 'Description': {'@xml:lang': 'en', '#text': 'Net operating balance'}}, {'@value': 'G6_F_NN', 'Description': {'@xml:lang': 'en', '#text': 'Net worth'}}, {'@value': 'G31_NN', 'Description': {'@xml:lang': 'en', '#text': 'Net/gross investment in nonfinancial assets'}}, {'@value': 'G28__Z', 'Description': {'@xml:lang': 'en', '#text': 'Other expense'}}, {'@value': 'G14__Z', 'Description': {'@xml:lang': 'en', '#text': 'Other revenue'}}, {'@value': 'GPB__Z', 'Description': {'@xml:lang': 'en', '#text': 'Primary net lending / borrowing'}}, {'@value': 'G1__Z', 'Description': {'@xml:lang': 'en', '#text': 'Revenue'}}, {'@value': 'G27__Z', 'Description': {'@xml:lang': 'en', '#text': 'Social benefits'}}, {'@value': 'G12__Z', 'Description': {'@xml:lang': 'en', '#text': 'Social contributions'}}, {'@value': 'G62_F', 'Description': {'@xml:lang': 'en', '#text': 'Stock position of financial assets'}}, {'@value': 'G63_F', 'Description': {'@xml:lang': 'en', '#text': 'Stock position of liabilities'}}, {'@value': 'G61_NN', 'Description':  ...

# %%
# Base URL for the IMF API
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'
key = 'Dataflow'  # Method to retrieve series information
search_term = 'Government Finance Statistics'  # Search term to find GSF

# Fetch the series list
response = requests.get(f'{url}{key}')
response.raise_for_status()  # Ensure the request was successful
series_list = response.json()['Structure']['Dataflows']['Dataflow']

# Extract data into a dictionary
data = []
gsf_ID = []
for series in series_list:
    if search_term in series['Name']['#text']:
        # Extract name and KeyFamilyID
        name = series['Name']['#text']
        key_family_id = series['KeyFamilyRef']['KeyFamilyID']
        
        # Add to list as a dictionary
        data.append({"name": name, "ID": key_family_id})
        gsf_ID.append(key_family_id)

# Convert to DataFrame
df = pd.DataFrame(data)

# Save cleaned DataFrame as a CSV file
df.to_csv('government_finance_statistics.csv', index=False, header=True)

# %%
# Initialize an empty list to collect data
data = []

for ID in gsf_ID:
    key = f"DataStructure/{ID}"  # Method / series
    try:
        response = requests.get(f"{url}{key}")
        response.raise_for_status()  # Ensure the request was successful
        
        # Extract the list of dimensions
        dimension_list = response.json() \
            ['Structure']['KeyFamilies']['KeyFamily'] \
            ['Components']['Dimension']

        for n, dimension in enumerate(dimension_list):
            # Append the ID and dimension details to the data list
            data.append({"ID": ID, "Dimension_Number": n+1, "Codelist": dimension['@codelist']})
            print(f"{ID}: Dimension {n+1}: {dimension['@codelist']}")

    except requests.exceptions.RequestException as e:
        print(f"Request failed for {ID}: {e}")
    except KeyError as e:
        print(f"KeyError for {ID}: {e}")

# Convert the collected data to a pandas DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Optionally save the DataFrame to a file (CSV, Excel, etc.)
df.to_csv("dimension_results.csv", index=False)
# Out:
# GFSMAB2016: Dimension 1: CL_FREQ
# GFSMAB2016: Dimension 2: CL_AREA_GFSMAB2016
# GFSMAB2016: Dimension 3: CL_SECTOR_GFSMAB2016
# GFSMAB2016: Dimension 4: CL_UNIT_GFSMAB2016
# GFSMAB2016: Dimension 5: CL_INDICATOR_GFSMAB2016
# GFSYFALCS2014: Dimension 1: CL_FREQ
# GFSYFALCS2014: Dimension 2: CL_AREA_GFSYFALCS2014
# GFSYFALCS2014: Dimension 3: CL_SECTOR_GFSYFALCS2014
# GFSYFALCS2014: Dimension 4: CL_UNIT_GFSYFALCS2014
# GFSYFALCS2014: Dimension 5: CL_INDICATOR_GFSYFALCS2014
# GFSYFALCS2014: Dimension 6: CL_COUNTERPART_SECTOR_GFSYFALCS2014
# GFSE2016: Dimension 1: CL_FREQ
# GFSE2016: Dimension 2: CL_AREA_GFSE2016
# GFSE2016: Dimension 3: CL_SECTOR_GFSE2016
# GFSE2016: Dimension 4: CL_UNIT_GFSE2016
# GFSE2016: Dimension 5: CL_INDICATOR_GFSE2016
# GFSIBS2016: Dimension 1: CL_FREQ
# GFSIBS2016: Dimension 2: CL_AREA_GFSIBS2016
# GFSIBS2016: Dimension 3: CL_SECTOR_GFSIBS2016
# GFSIBS2016: Dimension 4: CL_UNIT_GFSIBS2016
# GFSIBS2016: Dimension 5: CL_GFS_STO_GFSIBS2016
# GFSIBS2016: Dimension 6: CL_INSTR_ASSET_GFSIBS2016
# GFSIBS2016: Dimension 7: CL_COUNTERPART_AREA_GFSIBS2016
# GFSYIBS2014: Dimension 1: CL_FREQ
# GFSYIBS2014: Dimension 2: CL_AREA_GFSYIBS2014
# GFSYIBS2014: Dimension 3: CL_SECTOR_GFSYIBS2014
# GFSYIBS2014: Dimension 4: CL_UNIT_GFSYIBS2014
# GFSYIBS2014: Dimension 5: CL_GFS_STO_GFSYIBS2014
# GFSYIBS2014: Dimension 6: CL_INSTR_ASSET_GFSYIBS2014
# GFSYIBS2014: Dimension 7: CL_COUNTERPART_AREA_GFSYIBS2014
# GFSSSUC2016: Dimension 1: CL_FREQ
# GFSSSUC2016: Dimension 2: CL_AREA_GFSSSUC2016
# GFSSSUC2016: Dimension 3: CL_SECTOR_GFSSSUC2016
# GFSSSUC2015: Dimension 5: CL_INDICATOR_GFSSSUC2015
# GFSFALCS2017: Dimension 1: CL_FREQ
# GFSFALCS2017: Dimension 2: CL_AREA_GFSFALCS2017
# GFSFALCS2017: Dimension 3: CL_SECTOR_GFSFALCS2017
# GFSFALCS2017: Dimension 4: CL_UNIT_GFSFALCS2017
# GFSFALCS2017: Dimension 5: CL_INDICATOR_GFSFALCS2017
# GFSFALCS2017: Dimension 6: CL_COUNTERPART_SECTOR_GFSFALCS2017
# GFSYE2014: Dimension 1: CL_FREQ
# GFSYE2014: Dimension 2: CL_AREA_GFSYE2014
# GFSYE2014: Dimension 3: CL_SECTOR_GFSYE2014
# GFSYE2014: Dimension 4: CL_UNIT_GFSYE2014
# GFSYE2014: Dimension 5: CL_INDICATOR_GFSYE2014
# GFSCOFOG2017: Dimension 1: CL_FREQ
# GFSCOFOG2017: Dimension 2: CL_AREA_GFSCOFOG2017
# GFSCOFOG2017: Dimension 3: CL_SECTOR_GFSCOFOG2017
# GFSCOFOG2017: Dimension 4: CL_UNIT_GFSCOFOG2017
# GFSCOFOG2017: Dimension 5: CL_COFOG_GFSCOFOG2017
# GFSE2017: Dimension 1: CL_FREQ
# GFSE2017: Dimension 2: CL_AREA_GFSE2017
# GFSE2017: Dimension 3: CL_SECTOR_GFSE2017
# GFSE2017: Dimension 4: CL_UNIT_GFSE2017
# GFSE2017: Dimension 5: CL_INDICATOR_GFSE2017
# GFSR2017: Dimension 1: CL_FREQ
# GFSR2017: Dimension 2: CL_AREA_GFSR2017
# GFSR2017: Dimension 3: CL_SECTOR_GFSR2017
# GFSR2017: Dimension 4: CL_UNIT_GFSR2017
# GFSR2017: Dimension 5: CL_INDICATOR_GFSR2017
# GFSR2019: Dimension 1: CL_FREQ
# GFSR2019: Dimension 2: CL_AREA_GFSR2019
# GFSR2019: Dimension 3: CL_SECTOR_GFSR2019
# GFSR2019: Dimension 4: CL_UNIT_GFSR2019
# GFSR2019: Dimension 5: CL_INDICATOR_GFSR2019
# GFSSSUC2019: Dimension 1: CL_FREQ
# GFSSSUC2019: Dimension 2: CL_AREA_GFSSSUC2019
# GFSSSUC2019: Dimension 3: CL_SECTOR_GFSSSUC2019
# GFSSSUC2019: Dimension 4: CL_UNIT_GFSSSUC2019
# GFSSSUC2019: Dimension 5: CL_INDICATOR_GFSSSUC2019
# GFSE2019: Dimension 1: CL_FREQ
# GFSE2019: Dimension 2: CL_AREA_GFSE2019
# GFSE2019: Dimension 3: CL_OBJ41393180_GFSE2019
# GFSE2019: Dimension 4: CL_UNIT_GFSE2019
# GFSE2019: Dimension 5: CL_INDICATOR_GFSE2019
# GFSFALCS2019: Dimension 1: CL_FREQ
# GFSFALCS2019: Dimension 2: CL_AREA_GFSFALCS2019
# GFSFALCS2019: Dimension 3: CL_SECTOR_GFSFALCS2019
# GFSFALCS2019: Dimension 4: CL_UNIT_GFSFALCS2019
# GFSFALCS2019: Dimension 5: CL_INDICATOR_GFSFALCS2019
# GFSFALCS2019: Dimension 6: CL_COUNTERPART_SECTOR_GFSFALC
Dimension 6: CL_COUNTERPART_SECTOR_GFSFALCS2020
# GFSIBS2020: Dimension 1: CL_FREQ
# GFSIBS2020: Dimension 2: CL_AREA_GFSIBS2020
# GFSIBS2020: Dimension 3: CL_SECTOR_GFSIBS2020
# GFSIBS2020: Dimension 4: CL_UNIT_GFSIBS2020
# GFSIBS2020: Dimension 5: CL_GFS_STO_GFSIBS2020
# GFSIBS2020: Dimension 6: CL_INSTR_ASSET_GFSIBS2020
# GFSIBS2020: Dimension 7: CL_COUNTERPART_AREA_GFSIBS2020
# GFSE2020: Dimension 1: CL_FREQ
# GFSE2020: Dimension 2: CL_AREA_GFSE 2020
# GFSE2020: Dimension 3: CL_SECTOR_GFSE 2020
# GFSE2020: Dimension 4: CL_UNIT_GFSE 2020
# GFSE2020: Dimension 5: CL_INDICATOR_GFSE 2020
# GFSR: Dimension 1: CL_FREQ
# GFSR: Dimension 2: CL_AREA_GFSR
# GFSR: Dimension 3: CL_SECTOR_GFSR
# GFSR: Dimension 4: CL_UNIT_GFSR
# GFSR: Dimension 5: CL_INDICATOR_GFSR
# GFSSSUC: Dimension 1: CL_FREQ
# GFSSSUC: Dimension 2: CL_AREA_GFSSSUC
# GFSSSUC: Dimension 3: CL_SECTOR_GFSSSUC
# GFSSSUC: Dimension 4: CL_UNIT_GFSSSUC
# GFSSSUC: Dimension 5: CL_INDICATOR_GFSSSUC
# GFSCOFOG: Dimension 1: CL_FREQ
# GFSCOFOG: Dimension 2: CL_AREA_GFSCOFOG
# GFSCOFOG: Dimension 3: CL_SECTOR_GFSCOFOG
# GFSCOFOG: Dimension 4: CL_UNIT_GFSCOFOG
# GFSCOFOG: Dimension 5: CL_COFOG_GFSCOFOG
# GFSFALCS: Dimension 1: CL_FREQ
# GFSFALCS: Dimension 2: CL_AREA_GFSFALCS
# GFSFALCS: Dimension 3: CL_SECTOR_GFSFALCS
# GFSFALCS: Dimension 4: CL_UNIT_GFSFALCS
# GFSFALCS: Dimension 5: CL_INDICATOR_GFSFALCS
# GFSFALCS: Dimension 6: CL_COUNTERPART_SECTOR_GFSFALCS
# GFSIBS: Dimension 1: CL_FREQ
# GFSIBS: Dimension 2: CL_AREA_GFSIBS
# GFSIBS: Dimension 3: CL_SECTOR_GFSIBS
# GFSIBS: Dimension 4: CL_UNIT_GFSIBS
# GFSIBS: Dimension 5: CL_GFS_STO_GFSIBS
# GFSIBS: Dimension 6: CL_INSTR_ASSET_GFSIBS
# GFSIBS: Dimension 7: CL_COUNTERPART_AREA_GFSIBS
# GFSMAB: Dimension 1: CL_FREQ
# GFSMAB: Dimension 2: CL_AREA_GFSMAB
# GFSMAB: Dimension 3: CL_SECTOR_GFSMAB
# GFSMAB: Dimension 4: CL_UNIT_GFSMAB
# GFSMAB: Dimension 5: CL_INDICATOR_GFSMAB
# GFSE: Dimension 1: CL_FREQ
# GFSE: Dimension 2: CL_AREA_GFSE
# GFSE: Dimension 3: CL_SECTOR_GFSE
# GFSE: Dimension 4: CL_UNIT_GFSE
# GFSE: Dimension 5: CL_INDICATOR_GFSE
#              ID  Dimension_Number                 Codelist
# 0    GFSMAB2016                 1                  CL_FREQ
# 1    GFSMAB2016                 2       CL_AREA_GFSMAB2016
# 2    GFSMAB2016                 3     CL_SECTOR_GFSMAB2016
# 3    GFSMAB2016                 4       CL_UNIT_GFSMAB2016
# 4    GFSMAB2016                 5  CL_INDICATOR_GFSMAB2016
# ..          ...               ...                      ...
# 261        GFSE                 1                  CL_FREQ
# 262        GFSE                 2             CL_AREA_GFSE
# 263        GFSE                 3           CL_SECTOR_GFSE
# 264        GFSE                 4             CL_UNIT_GFSE
# 265        GFSE                 5        CL_INDICATOR_GFSE
#
# [266 rows x 3 columns]

# %% [markdown]
# TESTRUN GFSMAB2017

# %%
# Initialize an empty list to store the results
variable_data = []

test_df = df[df['ID']=='GFSMAB2017']
# Iterate through the unique codelists in the DataFrame
for codelist in test_df['Codelist'].unique():
    try:
        key = f"CodeList/{codelist}"
        response = requests.get(f"{url}{key}")
        response.raise_for_status()  # Ensure the request was successful

        # Extract codes and descriptions
        code_list = response.json()['Structure']['CodeLists']['CodeList']['Code']
        for code in code_list:
            variable_data.append({
                "Codelist": codelist,
                "Variable_Name": code['@value'],
                "Description": code['Description']['#text']
            })
            print(f"{codelist} - {code['Description']['#text']}: {code['@value']}")

    except requests.exceptions.RequestException as e:
        print(f"Request failed for codelist {codelist}: {e}")
    except KeyError as e:
        print(f"KeyError for codelist {codelist}: {e}")

# Convert the results into a DataFrame
variable_df = pd.DataFrame(variable_data)

# Display the resulting DataFrame
print(variable_df)

# Save the DataFrame to a file (optional)
variable_df.to_csv("variable_names_2017.csv", index=False)
# Out:
# KeyError for codelist CL_FREQ: 'Structure'
# CL_AREA_GFSMAB2017 - Afghanistan: AF
# CL_AREA_GFSMAB2017 - Albania: AL
# CL_AREA_GFSMAB2017 - Algeria: DZ
# CL_AREA_GFSMAB2017 - Angola: AO
# CL_AREA_GFSMAB2017 - Anguilla: AI
# CL_AREA_GFSMAB2017 - Antigua and Barbuda: AG
# CL_AREA_GFSMAB2017 - Argentina: AR
# CL_AREA_GFSMAB2017 - Armenia: AM
# CL_AREA_GFSMAB2017 - Aruba: AW
# CL_AREA_GFSMAB2017 - Australia: AU
# CL_AREA_GFSMAB2017 - Austria: AT
# CL_AREA_GFSMAB2017 - Azerbaijan: AZ
# CL_AREA_GFSMAB2017 - Bahamas: BS
# CL_AREA_GFSMAB2017 - Bahrain: BH
# CL_AREA_GFSMAB2017 - Bangladesh: BD
# CL_AREA_GFSMAB2017 - Barbados: BB
# CL_AREA_GFSMAB2017 - Belarus: BY
# CL_AREA_GFSMAB2017 - Belgium: BE
# CL_AREA_GFSMAB2017 - Belize: BZ
# CL_AREA_GFSMAB2017 - Benin: BJ
# CL_AREA_GFSMAB2017 - Bhutan: BT
# CL_AREA_GFSMAB2017 - Bolivia: BO
# CL_AREA_GFSMAB2017 - Bosnia and Herzegovina: BA
# CL_AREA_GFSMAB2017 - Botswana: BW
# CL_AREA_GFSMAB2017 - Brazil: BR
# CL_AREA_GFSMAB2017 - Brunei Darussalam: BN
# CL_AREA_GFSMAB2017 - Bulgaria: BG
# CL_AREA_GFSMAB2017 - Burkina Faso: BF
# CL_AREA_GFSMAB2017 - Burundi: BI
# CL_AREA_GFSMAB2017 - Cape Verde: CV
# CL_AREA_GFSMAB2017 - Cambodia: KH
# CL_AREA_GFSMAB2017 - Cameroon: CM
# CL_AREA_GFSMAB2017 - Canada: CA
# CL_INDICATOR_GFSMAB2017 - Net debt: G63N_FD4
# CL_INDICATOR_GFSMAB2017 - Net financial worth: G6M2_F
# CL_INDICATOR_GFSMAB2017 - Net incurrence of liabilities: G33_F
# CL_INDICATOR_GFSMAB2017 - Net lending (+) / Net borrowing (-): GNLB__Z
# CL_INDICATOR_GFSMAB2017 - Net operating balance: GNOB__Z
# CL_INDICATOR_GFSMAB2017 - Net worth: G6_F_NN
# CL_INDICATOR_GFSMAB2017 - Net/gross investment in nonfinancial assets: G31_NN
# CL_INDICATOR_GFSMAB2017 - Other expense: G28__Z
# CL_INDICATOR_GFSMAB2017 - Other revenue: G14__Z
# CL_INDICATOR_GFSMAB2017 - Primary net lending / borrowing: GPB__Z
# CL_INDICATOR_GFSMAB2017 - Revenue: G1__Z
# CL_INDICATOR_GFSMAB2017 - Social benefits: G27__Z
# CL_INDICATOR_GFSMAB2017 - Social contributions: G12__Z
# CL_INDICATOR_GFSMAB2017 - Stock position of financial assets: G62_F
# CL_INDICATOR_GFSMAB2017 - Stock position of liabilities: G63_F
# CL_INDICATOR_GFSMAB2017 - Stock position of nonfinancial assets: G61_NN
# CL_INDICATOR_GFSMAB2017 - Subsidies: G25__Z
# CL_INDICATOR_GFSMAB2017 - Tax revenue: G11__Z
# CL_INDICATOR_GFSMAB2017 - Use of goods and services: G22__Z
#                     Codelist Variable_Name  \
# 0         CL_AREA_GFSMAB2017            AF
# 1         CL_AREA_GFSMAB2017            AL
# 2         CL_AREA_GFSMAB2017            DZ
# 3         CL_AREA_GFSMAB2017            AO
# 4         CL_AREA_GFSMAB2017            AI
# ..                       ...           ...
# 259  CL_INDICATOR_GFSMAB2017         G63_F
# 260  CL_INDICATOR_GFSMAB2017        G61_NN
# 261  CL_INDICATOR_GFSMAB2017        G25__Z
# 262  CL_INDICATOR_GFSMAB2017        G11__Z
# 263  CL_INDICATOR_GFSMAB2017        G22__Z
#
#                                Description
# 0                              Afghanistan
# 1                                  Albania
# 2                                  Algeria
# 3                                   Angola
# 4                                 Anguilla
# ..                                     ...
# 259          Stock position of liabilities
# 260  Stock position of nonfinancial assets
# 261                              Subsidies
# 262                            Tax revenue
# 263              Use of goods and services
#
# [264 rows x 3 columns]

# %%
# Initialize an empty list to store the results
variable_data = []

# Iterate through the unique codelists in the DataFrame
for codelist in df['Codelist'].unique():
    try:
        key = f"CodeList/{codelist}"
        response = requests.get(f"{url}{key}")
        response.raise_for_status()  # Ensure the request was successful

        # Extract codes and descriptions
        code_list = response.json()['Structure']['CodeLists']['CodeList']['Code']
        for code in code_list:
            variable_data.append({
                "Codelist": codelist,
                "Variable_Name": code['@value'],
                "Description": code['Description']['#text']
            })
            print(f"{codelist} - {code['Description']['#text']}: {code['@value']}")

    except requests.exceptions.RequestException as e:
        print(f"Request failed for codelist {codelist}: {e}")
    except KeyError as e:
        print(f"KeyError for codelist {codelist}: {e}")

# Convert the results into a DataFrame
variable_df = pd.DataFrame(variable_data)

# Display the resulting DataFrame
print(variable_df)

# Save the DataFrame to a file (optional)
variable_df.to_csv("variable_names.csv", index=False)
